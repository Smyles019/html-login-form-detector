# %% [markdown]
# <a href="https://colab.research.google.com/github/Smyles019/html-login-form-detector/blob/svm-evaluation/notebooks/Model_Testing_Tutorial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %cd /content
# !rm -rf html-login-form-detector
# !git clone -b svm-evaluation https://github.com/Smyles019/html-login-form-detector.git
# %cd html-login-form-detector
# !pip install -r requirements.txt
# Out:
# /content
# Cloning into 'html-login-form-detector'...
# remote: Enumerating objects: 125, done.
# remote: Counting objects: 100% (125/125), done.
# remote: Compressing objects: 100% (108/108), done.
# remote: Total 125 (delta 45), reused 41 (delta 11), pack-reused 0 (from 0)
# Receiving objects: 100% (125/125), 397.06 KiB | 2.63 MiB/s, done.
# Resolving deltas: 100% (45/45), done.
# /content/html-login-form-detector
# Requirement already satisfied: pandas in /usr/local/lib/python3.13/dist-packages (from -r requirements.txt (line 1)) (2.2.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.13/dist-packages (from -r requirements.txt (line 2)) (2.1.3)
# Requirement already satisfied: scipy in /usr/local/lib/python3.13/dist-packages (from -r requirements.txt (line 3)) (1.16.3)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.13/dist-packages (from -r requirements.txt (line 4)) (1.6.1)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.13/dist-packages (from -r requirements.txt (line 5)) (3.10.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.13/dist-packages (from pandas->-r requirements.txt (line 1)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.13/dist-packages (from pandas->-r requirements.txt (line 1)) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.13/dist-packages (from pandas->-r requirements.txt (line 1)) (2026.3)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.13/dist-packages (from scikit-learn->-r requirements.txt (line 4)) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.13/dist-packages (from scikit-learn->-r requirements.txt (line 4)) (3.6.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.13/dist-packages (from matplotlib->-r requirements.txt (line 5)) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.13/dist-packages (from matplotlib->-r requirements.txt (line 5)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.13/dist-packages (from matplotlib->-r requirements.txt (line 5)) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.13/dist-packages (from matplotlib->-r requirements.txt (line 5)) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.13/dist-packages (from matplotlib->-r requirements.txt (line 5)) (26.3)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.13/dist-packages (from matplotlib->-r requirements.txt (line 5)) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.13/dist-packages (from matplotlib->-r requirements.txt (line 5)) (3.3.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.13/dist-packages (from python-dateutil>=2.8.2->pandas->-r requirements.txt (line 1)) (1.17.0)

# %% [markdown]
# # Welcome to Model Testing! (A Guide for Beginners)
#
# If you are new to Machine Learning, this guide will walk you through exactly what we are doing, how to run the code, and how to explain the results to your group members or project supervisor.
#
# ---
#
# ### 1. The Structure of Our Code
#
# To make things easy to understand and test, the code has been broken down into three logical steps located in the `src/` folder:
#
# 1. **`data_processing.py`**: This script does the "dirty work." It loads the raw CSV files, handles missing values, and turns raw HTML signatures into numbers that a computer can understand (like counting how many `<form>` tags there are).
# 2. **`train_model.py`**: This script takes the clean data, splits it into two piles (one pile for the model to *learn* from, and a smaller pile kept hidden to *test* the model later). It trains the Logistic Regression baseline model and saves it.
# 3. **`evaluate_model.py`**: This is the script you will use the most! It loads the hidden test data and the trained model, and tells you exactly how well the model performed using plain-English explanations.
#
# ---
#
# ### 2. How to Test the Model
#
# To test the model, you simply need to run the two scripts. You can run these commands in your terminal (make sure you are in the project's root folder `html-login-form-detector`):

# %%
# !python src/train_model.py
# Out:
# Loading data from data/raw/Dataset 1/train_login_form.csv and data/raw/Dataset 1/train_no_form.csv...
# Extracting structural features from HTML signatures...
# Extracting N-gram features...
# Scaling structural features...
# Combining structural and N-gram features...
# Training Support Vector Machine (LinearSVC) model...
# /usr/local/lib/python3.13/dist-packages/sklearn/svm/_base.py:1249: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Model training complete.
# Saved trained model, preprocessors, and test data successfully.

# %%
# !python src/evaluate_model.py
# Out:
# Loading test data and model artifacts...
# Evaluating the model on unseen test data...
#
#
# --- CONFUSION MATRIX EXPLAINED ---
# True Positives (TP): 98 pages were correctly identified as MALICIOUS phishing forms.
# True Negatives (TN): 128 pages were correctly identified as BENIGN (normal) pages.
#
# False Positives (FP): 8 benign pages were INCORRECTLY flagged as malicious.
#   -> Meaning: Legitimate users or admins might be blocked or warned unnecessarily.
# False Negatives (FN): 3 malicious phishing pages were MISSED by the model.
#   -> Meaning: This is dangerous. These are phishing attacks that slipped past our defense.
#
# --- PERFORMANCE METRICS ---
#                precision    recall  f1-score   support
#
#    Benign (0)       0.98      0.94      0.96       136
# Malicious (1)       0.92      0.97      0.95       101
#
#      accuracy                           0.95       237
#     macro avg       0.95      0.96      0.95       237
#  weighted avg       0.95      0.95      0.95       237
#
# How to interpret these numbers:
# - Precision (Malicious): When the model says 'This is phishing', how often is it actually right?
# - Recall (Malicious): Out of ALL the real phishing pages in the test set, what percentage did we successfully catch?
# - F1-Score: A balanced average between Precision and Recall. High F1 means the model is both accurate and catches most attacks.
#
# --- WHAT IS THE MODEL LOOKING AT? (Top Features) ---
# Top 10 features that flag a page as MALICIOUS (Positive importance):
#                  feature  importance
#   pattern: div div label    0.192844
#        unique_tags_count    0.192757
#  pattern: label span div    0.158632
#        pattern: span div    0.139560
#    pattern: a div script    0.126715
# pattern: span div iframe    0.124713
#   pattern: div input img    0.122994
#                max_depth    0.121360
#   pattern: div div input    0.119390
#       pattern: input img    0.112730
#
# Top 10 features that flag a page as BENIGN (Negative importance):
#                    feature  importance
#   pattern: input div label   -0.192894
#       pattern: label input   -0.121168
#      pattern: noscript div   -0.118212
#       pattern: div span ul   -0.110133
# pattern: input label input   -0.098440
#         pattern: span span   -0.096894
#    pattern: iframe div div   -0.096342
#    pattern: script div div   -0.096153
#      pattern: noscript img   -0.088730
#  pattern: div input button   -0.087381

# %% [markdown]
# ---
#
# ### 3. How to Explain the Results to Your Group
#
# When you run `evaluate_model.py`, it will print out several metrics. Here is how you can interpret and explain them:
#
# #### A. The Confusion Matrix
# The confusion matrix is just a 2x2 grid that shows where the model got things right and where it got confused.
# - **True Positives (TP):** The model caught a phishing page successfully. (YAY!)
# - **True Negatives (TN):** The model looked at a normal page and left it alone. (YAY!)
# - **False Positives (FP):** The model panicked and flagged a normal page as phishing. (Oops... this means legitimate users might get blocked from logging into their accounts).
# - **False Negatives (FN):** The model missed a phishing page. (DANGER! This means an attacker successfully sneaked past our system).
#
# *How to explain it:* "Our model caught [TP] phishing forms, but it completely missed [FN] of them. However, it also accidentally flagged [FP] normal pages, which we need to minimize so we don't annoy real users."
#
# #### B. Precision and Recall
# - **Precision:** "Out of all the pages our model *claimed* were phishing, how many actually were?" If precision is low, our system cries "wolf" too often.
# - **Recall:** "Out of all the *actual* phishing pages that existed in the test, what percentage did we catch?" If recall is low, our system is blind to many attacks.
# - **F1-Score:** This is just a balanced average of Precision and Recall. It's a great single number to look at to see if the model is good overall.
#
# #### C. Feature Importance (What is the model thinking?)
# Machine Learning isn't magic. The Logistic Regression model assigns a "weight" (or importance) to every single HTML tag or pattern it sees.
#
# If a feature has a **HIGH POSITIVE weight**, the model thinks: *"When I see this tag, it's highly likely to be a phishing attack!"*
# If a feature has a **HIGH NEGATIVE weight**, the model thinks: *"When I see this tag, it's probably a safe, benign page."*
#
# *How to explain it:* "We looked under the hood of the model, and it turns out that phishing pages often have a very specific structure. For example, our model learned that if a page has a high number of [Feature X], it's very likely to be malicious. This proves that attackers are indeed reusing HTML templates!"
